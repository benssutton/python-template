# %%
import polars as pl

df = pl.DataFrame([["Alpha","Beta", "Gamma"],[1,2,3]],schema=["name", "value"])\
    .with_row_index("id")
df
# Out:
# shape: (3, 3)
# ┌─────┬───────┬───────┐
# │ id  ┆ name  ┆ value │
# │ --- ┆ ---   ┆ ---   │
# │ u32 ┆ str   ┆ i64   │
# ╞═════╪═══════╪═══════╡
# │ 0   ┆ Alpha ┆ 1     │
# │ 1   ┆ Beta  ┆ 2     │
# │ 2   ┆ Gamma ┆ 3     │
# └─────┴───────┴───────┘

# %%
df.write_ipc("./clickhouse_seed_data.ipc")
